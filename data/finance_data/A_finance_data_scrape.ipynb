# %% [markdown]
# # Get all necesarry Finance Data and combine on one Frame

# %% [markdown]
# ### get Data from Yahoo Finance Data

# %%
import yfinance as yf

# S&P 500 Index from Yahoo Finance
sp500_data = yf.Ticker("^GSPC")

# Download historical data for the last 15 years
sp500_data = sp500_data.history(period="15y", interval="1d")

#print the first few rows of the data
print(sp500_data.head())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-06-21 00:00:00-04:00  1122.790039  1131.229980  1108.239990  1113.199951
# 2010-06-22 00:00:00-04:00  1113.900024  1118.500000  1094.180054  1095.310059
# 2010-06-23 00:00:00-04:00  1095.569946  1099.640015  1085.310059  1092.040039
# 2010-06-24 00:00:00-04:00  1090.930054  1090.930054  1071.599976  1073.689941
# 2010-06-25 00:00:00-04:00  1075.099976  1083.560059  1067.890015  1076.760010
#
#                                Volume  Dividends  Stock Splits
# Date
# 2010-06-21 00:00:00-04:00  4514360000        0.0           0.0
# 2010-06-22 00:00:00-04:00  4514380000        0.0           0.0
# 2010-06-23 00:00:00-04:00  4526150000        0.0           0.0
# 2010-06-24 00:00:00-04:00  4814830000        0.0           0.0
# 2010-06-25 00:00:00-04:00  5128840000        0.0           0.0

# %%
import matplotlib.pyplot as plt

# Plot the 'Close' prices over time
plt.figure(figsize=(12, 6))
plt.plot(sp500_data.index, sp500_data['Close'], label='S&P 500 Close Price', color='blue')
plt.title('S&P 500 Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### get Bitcoin Data from Yahoo Finance

# %%
# Bitcoin data from Yahoo Finance
btc = yf.Ticker("BTC-USD")

# Download historical data for the last 15 years
btc_data = btc.history(period="15y", interval="1d")

# Display the first rows of the data
print(btc_data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00  21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00  34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00  37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00  36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00  26580100        0.0           0.0

# %%
# Plot the 'Close' prices of Bitcoin over time
plt.figure(figsize=(12, 6))
plt.plot(btc_data.index, btc_data['Close'], label='Bitcoin Close Price', color='orange')
plt.title('Bitcoin Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Get the NASDAQ Data from Yahoo Finance

# %%
# NASDAQ data from Yahoo Finance
nasdaq = yf.Ticker("^IXIC")

# Download historical data for the last 15 years
nasdaq_data = nasdaq.history(period="15y", interval="1d")

# Display the first rows of the data
print(nasdaq_data.head())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-06-21 00:00:00-04:00  2341.110107  2341.110107  2277.729980  2289.090088
# 2010-06-22 00:00:00-04:00  2296.830078  2313.719971  2259.590088  2261.800049
# 2010-06-23 00:00:00-04:00  2264.409912  2271.739990  2236.989990  2254.229980
# 2010-06-24 00:00:00-04:00  2246.199951  2247.419922  2213.500000  2217.419922
# 2010-06-25 00:00:00-04:00  2224.729980  2240.879883  2205.919922  2223.479980
#
#                                Volume  Dividends  Stock Splits
# Date
# 2010-06-21 00:00:00-04:00  1910700000        0.0           0.0
# 2010-06-22 00:00:00-04:00  1934450000        0.0           0.0
# 2010-06-23 00:00:00-04:00  1929450000        0.0           0.0
# 2010-06-24 00:00:00-04:00  2064360000        0.0           0.0
# 2010-06-25 00:00:00-04:00  3540350000        0.0           0.0

# %%
# Plot the 'Close' prices of NASDAQ over time
plt.figure(figsize=(12, 6))
plt.plot(nasdaq_data.index, nasdaq_data['Close'], label='NASDAQ Close Price', color='green')
plt.title('NASDAQ Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Get the Tesla Data from Yahoo Finance

# %%
# Tesla data from Yahoo Finance
tsla = yf.Ticker("TSLA")

# Download historical data for the last 15 years
tsla_data = tsla.history(period="15y", interval="1d")

# Display the first rows of the data
print(tsla_data.head())
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
plt.figure(figsize=(12, 6))
plt.plot(tsla_data.index, tsla_data['Close'], label='Tesla Close Price', color='purple')
plt.title('Tesla Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### combine in one Dataset

# %%
import pandas as pd

# Normalize and align all indices (remove timezone and set to midnight)
sp500_data.index = pd.to_datetime(sp500_data.index).tz_localize(None).normalize()
btc_data.index = pd.to_datetime(btc_data.index).tz_localize(None).normalize()
nasdaq_data.index = pd.to_datetime(nasdaq_data.index).tz_localize(None).normalize()
tsla_data.index = pd.to_datetime(tsla_data.index).tz_localize(None).normalize()

# Ensure all datasets have the same date range
start_date = max(sp500_data.index.min(), btc_data.index.min(), nasdaq_data.index.min(), tsla_data.index.min())
end_date = min(sp500_data.index.max(), btc_data.index.max(), nasdaq_data.index.max(), tsla_data.index.max())
sp500_data = sp500_data[(sp500_data.index >= start_date) & (sp500_data.index <= end_date)]
btc_data = btc_data[(btc_data.index >= start_date) & (btc_data.index <= end_date)]
nasdaq_data = nasdaq_data[(nasdaq_data.index >= start_date) & (nasdaq_data.index <= end_date)]
tsla_data = tsla_data[(tsla_data.index >= start_date) & (tsla_data.index <= end_date)]

# Rename columns to avoid collision
sp500_data = sp500_data.rename(columns={'Close': 'sp500_close', 'Volume': 'sp500_volume'})
btc_data = btc_data.rename(columns={'Close': 'bitcoin_close', 'Volume': 'bitcoin_volume'})
nasdaq_data = nasdaq_data.rename(columns={'Close': 'nasdaq_close', 'Volume': 'nasdaq_volume'})
tsla_data = tsla_data.rename(columns={'Close': 'tesla_close', 'Volume': 'tesla_volume'})

# Plot the adjusted datasets to ensure alignment
plt.figure(figsize=(14, 7))
plt.plot(sp500_data.index, sp500_data['sp500_close'], label='S&P 500 Close', color='blue')
plt.plot(btc_data.index, btc_data['bitcoin_close'], label='Bitcoin Close', color='orange')
plt.plot(nasdaq_data.index, nasdaq_data['nasdaq_close'], label='NASDAQ Close', color='green')
plt.plot(tsla_data.index, tsla_data['tesla_close'], label='Tesla Close', color='purple')
plt.title('Aligned Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
sp500_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2706 entries, 2014-09-17 to 2025-06-20
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2706 non-null   float64
#  1   High          2706 non-null   float64
#  2   Low           2706 non-null   float64
#  3   sp500_close   2706 non-null   float64
#  4   sp500_volume  2706 non-null   int64
#  5   Dividends     2706 non-null   float64
#  6   Stock Splits  2706 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 169.1 KB

# %%
# --- Vorbereitung: Date-Spalte sicherstellen ---
for df in [sp500_data, btc_data, nasdaq_data, tsla_data]:
    if 'Date' not in df.columns:
        df.reset_index(inplace=True)  # holt 'Date' aus dem Index
    df['Date'] = pd.to_datetime(df['Date'])

# --- Merge auf Close-Preise ---
combined_data_close = sp500_data[['Date', 'sp500_close']].merge(
    btc_data[['Date', 'bitcoin_close']], on='Date', how='outer'
).merge(
    nasdaq_data[['Date', 'nasdaq_close']], on='Date', how='outer'
).merge(
    tsla_data[['Date', 'tesla_close']], on='Date', how='outer'
)

# --- Merge auf Volumen ---
combined_data_volume = sp500_data[['Date', 'sp500_volume']].merge(
    btc_data[['Date', 'bitcoin_volume']], on='Date', how='outer'
).merge(
    nasdaq_data[['Date', 'nasdaq_volume']], on='Date', how='outer'
).merge(
    tsla_data[['Date', 'tesla_volume']], on='Date', how='outer'
)

# --- Nach Datum sortieren (optional, aber empfohlen) ---
combined_data_close.sort_values('Date', inplace=True)
combined_data_volume.sort_values('Date', inplace=True)

# %%
# Plot the merged close prices
plt.figure(figsize=(14, 7))
plt.plot(combined_data_close.index, combined_data_close['sp500_close'], label='S&P 500 Close', color='blue')
plt.plot(combined_data_close.index, combined_data_close['bitcoin_close'], label='Bitcoin Close', color='orange')
plt.plot(combined_data_close.index, combined_data_close['nasdaq_close'], label='NASDAQ Close', color='green')
plt.plot(combined_data_close.index, combined_data_close['tesla_close'], label='Tesla Close', color='purple')
plt.title('Merged Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Merge explizit auf 'Date'
merged_data = pd.merge(
    combined_data_close, combined_data_volume,
    on='Date', how='outer'
)

# Optional: zurücksortieren und Index setzen
merged_data.sort_values('Date', inplace=True)

# Vorschau
print(merged_data.head())
# Out:
#         Date  sp500_close  bitcoin_close  nasdaq_close  tesla_close  \
# 0 2014-09-17  2001.569946     457.334015   4562.189941    17.425333
# 1 2014-09-18  2011.359985     424.440002   4593.430176    17.587999
# 2 2014-09-19  2010.400024     394.795990   4579.790039    17.288000
# 3 2014-09-20          NaN     408.903992           NaN          NaN
# 4 2014-09-21          NaN     398.821014           NaN          NaN
#
#    sp500_volume  bitcoin_volume  nasdaq_volume  tesla_volume
# 0  3.209420e+09        21056800   1.796710e+09    77665500.0
# 1  3.235340e+09        34483200   1.774840e+09    55389000.0
# 2  4.880220e+09        37919700   3.178490e+09   102163500.0
# 3           NaN        36863600            NaN           NaN
# 4           NaN        26580100            NaN           NaN

# %% [markdown]
# ### write

# %%
merged_data.to_csv("financeData_target_variables.csv", index=False)

sp500_data.to_csv("temporary_files/sp500_data.csv", index=False)
tsla_data.to_csv("temporary_files/tsla_data.csv", index=False)
btc_data.to_csv("temporary_files/btc_data.csv", index=False)
nasdaq_data.to_csv("temporary_files/nasdaq_data.csv", index=False)
