# %% [markdown]
# # Get all necesarry Finance Data and combine on one Frame

# %% [markdown]
# ### get sp500 data from Yahoo Finance Data

# %%
import yfinance as yf

# S&P 500 Index from Yahoo Finance
sp500_data = yf.Ticker("^GSPC")

# Download historical data for the last 15 years
sp500_data = sp500_data.history(period="15y", interval="1d")

#print the first few rows of the data
print(sp500_data.head())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-07-06 00:00:00-04:00  1028.089966  1042.500000  1018.349976  1028.060059
# 2010-07-07 00:00:00-04:00  1028.540039  1060.890015  1028.540039  1060.270020
# 2010-07-08 00:00:00-04:00  1062.920044  1071.250000  1058.239990  1070.250000
# 2010-07-09 00:00:00-04:00  1070.500000  1078.160034  1068.099976  1077.959961
# 2010-07-12 00:00:00-04:00  1077.229980  1080.780029  1070.449951  1078.750000
#
#                                Volume  Dividends  Stock Splits
# Date
# 2010-07-06 00:00:00-04:00  4691240000        0.0           0.0
# 2010-07-07 00:00:00-04:00  4931220000        0.0           0.0
# 2010-07-08 00:00:00-04:00  4548460000        0.0           0.0
# 2010-07-09 00:00:00-04:00  3506570000        0.0           0.0
# 2010-07-12 00:00:00-04:00  3426990000        0.0           0.0

# %%
import matplotlib.pyplot as plt

# Plot the 'Close' prices over time
plt.figure(figsize=(12, 6))
plt.plot(sp500_data.index, sp500_data['Close'], label='S&P 500 Close Price', color='blue')
plt.title('S&P 500 Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### get Bitcoin Data from Yahoo Finance

# %%
# Bitcoin data from Yahoo Finance
btc = yf.Ticker("BTC-USD")

# Download historical data for the last 15 years
btc_data = btc.history(period="15y", interval="1d")

# Display the first rows of the data
print(btc_data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00  21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00  34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00  37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00  36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00  26580100        0.0           0.0

# %%
# Plot the 'Close' prices of Bitcoin over time
plt.figure(figsize=(12, 6))
plt.plot(btc_data.index, btc_data['Close'], label='Bitcoin Close Price', color='orange')
plt.title('Bitcoin Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Get NASDAQ Data from Yahoo Finance

# %%
# NASDAQ data from Yahoo Finance
nasdaq = yf.Ticker("^IXIC")

# Download historical data for the last 15 years
nasdaq_data = nasdaq.history(period="15y", interval="1d")

# Display the first rows of the data
print(nasdaq_data.head())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2010-07-06 00:00:00-04:00  2122.280029  2136.300049  2077.770020  2093.879883
# 2010-07-07 00:00:00-04:00  2099.659912  2159.790039  2098.110107  2159.469971
# 2010-07-08 00:00:00-04:00  2174.959961  2181.300049  2150.189941  2175.399902
# 2010-07-09 00:00:00-04:00  2174.199951  2196.949951  2170.760010  2196.449951
# 2010-07-12 00:00:00-04:00  2194.120117  2213.389893  2183.520020  2198.360107
#
#                                Volume  Dividends  Stock Splits
# Date
# 2010-07-06 00:00:00-04:00  2173030000        0.0           0.0
# 2010-07-07 00:00:00-04:00  2199500000        0.0           0.0
# 2010-07-08 00:00:00-04:00  2034030000        0.0           0.0
# 2010-07-09 00:00:00-04:00  1592610000        0.0           0.0
# 2010-07-12 00:00:00-04:00  1767970000        0.0           0.0

# %%
# Plot the 'Close' prices of NASDAQ over time
plt.figure(figsize=(12, 6))
plt.plot(nasdaq_data.index, nasdaq_data['Close'], label='NASDAQ Close Price', color='green')
plt.title('NASDAQ Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Get Tesla Data from Yahoo Finance

# %%
# Tesla data from Yahoo Finance
tsla = yf.Ticker("TSLA")

# Download historical data for the last 15 years
tsla_data = tsla.history(period="15y", interval="1d")

# Display the first rows of the data
print(tsla_data.head())
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
# 2010-07-07 00:00:00-04:00  1.093333  1.108667  0.998667  1.053333  103825500
# 2010-07-08 00:00:00-04:00  1.076000  1.168000  1.038000  1.164000  115671000
# 2010-07-09 00:00:00-04:00  1.172000  1.193333  1.103333  1.160000   60759000
# 2010-07-12 00:00:00-04:00  1.196667  1.204667  1.133333  1.136667   33037500
#
#                            Dividends  Stock Splits
# Date
# 2010-07-06 00:00:00-04:00        0.0           0.0
# 2010-07-07 00:00:00-04:00        0.0           0.0
# 2010-07-08 00:00:00-04:00        0.0           0.0
# 2010-07-09 00:00:00-04:00        0.0           0.0
# 2010-07-12 00:00:00-04:00        0.0           0.0

# %%
plt.figure(figsize=(12, 6))
plt.plot(tsla_data.index, tsla_data['Close'], label='Tesla Close Price', color='purple')
plt.title('Tesla Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## combine in one Dataset

# %%
import pandas as pd

# Normalize and align all indices (remove timezone and set to midnight)
sp500_data.index = pd.to_datetime(sp500_data.index).tz_localize(None).normalize()
btc_data.index = pd.to_datetime(btc_data.index).tz_localize(None).normalize()
nasdaq_data.index = pd.to_datetime(nasdaq_data.index).tz_localize(None).normalize()
tsla_data.index = pd.to_datetime(tsla_data.index).tz_localize(None).normalize()

# Ensure all datasets have the same date range
start_date = max(sp500_data.index.min(), btc_data.index.min(), nasdaq_data.index.min(), tsla_data.index.min())
end_date = min(sp500_data.index.max(), btc_data.index.max(), nasdaq_data.index.max(), tsla_data.index.max())
sp500_data = sp500_data[(sp500_data.index >= start_date) & (sp500_data.index <= end_date)]
btc_data = btc_data[(btc_data.index >= start_date) & (btc_data.index <= end_date)]
nasdaq_data = nasdaq_data[(nasdaq_data.index >= start_date) & (nasdaq_data.index <= end_date)]
tsla_data = tsla_data[(tsla_data.index >= start_date) & (tsla_data.index <= end_date)]

# Rename columns to avoid collision and fit to the desired format
sp500_data = sp500_data.rename(columns={'Close': 'sp500_stockprice', 'Volume': 'sp500_volume'})
btc_data = btc_data.rename(columns={'Close': 'bitcoin_stockprice', 'Volume': 'bitcoin_volume'})
nasdaq_data = nasdaq_data.rename(columns={'Close': 'nasdaq_stockprice', 'Volume': 'nasdaq_volume'})
tsla_data = tsla_data.rename(columns={'Close': 'tesla_stockprice', 'Volume': 'tesla_volume'})

# Plot the adjusted datasets to ensure alignment
plt.figure(figsize=(14, 7))
plt.plot(sp500_data.index, sp500_data['sp500_stockprice'], label='S&P 500 Close', color='blue')
plt.plot(btc_data.index, btc_data['bitcoin_stockprice'], label='Bitcoin Close', color='orange')
plt.plot(nasdaq_data.index, nasdaq_data['nasdaq_stockprice'], label='NASDAQ Close', color='green')
plt.plot(tsla_data.index, tsla_data['tesla_stockprice'], label='Tesla Close', color='purple')
plt.title('Aligned Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 9
#       6 nasdaq_data.index = pd.to_datetime(nasdaq_data.index).tz_localize(None).normalize()
#       7 tsla_data.index = pd.to_datetime(tsla_data.index).tz_localize(None).normalize()
# ----> 9 sp500_data.index = pd.to_datetime(sp500_data.index).tz_convert("US/Eastern")
#      10 btc_data.index = pd.to_datetime(btc_data.index).tz_convert("US/Eastern")
#      11 nasdaq_data.index = pd.to_datetime(nasdaq_data.index).tz_convert("US/Eastern")
#
# File ~\miniconda3\envs\VollVertnuettelt\lib\site-packages\pandas\core\indexes\datetimes.py:283, in DatetimeIndex.tz_convert(self, tz)
#     281 @doc(DatetimeArray.tz_convert)
#     282 def tz_convert(self, tz) -> Self:
# --> 283     arr = self._data.tz_convert(tz)
#     284     return type(self)._simple_new(arr, name=self.name, refs=self._references)
#
# ...

# %%
sp500_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2706 entries, 2014-09-17 to 2025-06-20
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2706 non-null   float64
#  1   High              2706 non-null   float64
#  2   Low               2706 non-null   float64
#  3   sp500_stockprice  2706 non-null   float64
#  4   sp500_volume      2706 non-null   int64
#  5   Dividends         2706 non-null   float64
#  6   Stock Splits      2706 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 169.1 KB

# %%
# --- Vorbereitung: Date-Spalte sicherstellen ---
for df in [sp500_data, btc_data, nasdaq_data, tsla_data]:
    if 'Date' not in df.columns:
        df.reset_index(inplace=True)  # holt 'Date' aus dem Index
    df['Date'] = pd.to_datetime(df['Date'])

# --- Merge auf stockprice-Preise ---
combined_data_stockprice = sp500_data[['Date', 'sp500_stockprice']].merge(
    btc_data[['Date', 'bitcoin_stockprice']], on='Date', how='outer'
).merge(
    nasdaq_data[['Date', 'nasdaq_stockprice']], on='Date', how='outer'
).merge(
    tsla_data[['Date', 'tesla_stockprice']], on='Date', how='outer'
)

# --- Merge auf Volumen ---
combined_data_volume = sp500_data[['Date', 'sp500_volume']].merge(
    btc_data[['Date', 'bitcoin_volume']], on='Date', how='outer'
).merge(
    nasdaq_data[['Date', 'nasdaq_volume']], on='Date', how='outer'
).merge(
    tsla_data[['Date', 'tesla_volume']], on='Date', how='outer'
)

# --- Nach Datum sortieren (optional, aber empfohlen) ---
combined_data_stockprice.sort_values('Date', inplace=True)
combined_data_volume.sort_values('Date', inplace=True)

# %%
# Plot the merged stockprice values
plt.figure(figsize=(14, 7))
plt.plot(combined_data_stockprice.index, combined_data_stockprice['sp500_stockprice'], label='S&P 500 stockprice', color='blue')
plt.plot(combined_data_stockprice.index, combined_data_stockprice['bitcoin_stockprice'], label='Bitcoin stockprice', color='orange')
plt.plot(combined_data_stockprice.index, combined_data_stockprice['nasdaq_stockprice'], label='NASDAQ stockprice', color='green')
plt.plot(combined_data_stockprice.index, combined_data_stockprice['tesla_stockprice'], label='Tesla stockprice', color='purple')
plt.title('Merged stockprice values (close prices) Over Time')
plt.xlabel('Date')
plt.ylabel('stockprice value/Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Merge explizit auf 'Date'
merged_data = pd.merge(
    combined_data_stockprice, combined_data_volume,
    on='Date', how='outer'
)

# Optional: zurücksortieren und Index setzen
merged_data.sort_values('Date', inplace=True)

# Vorschau
print(merged_data.head())
# Out:
#         Date  sp500_stockprice  bitcoin_stockprice  nasdaq_stockprice  \
# 0 2014-09-17       2001.569946          457.334015        4562.189941
# 1 2014-09-18       2011.359985          424.440002        4593.430176
# 2 2014-09-19       2010.400024          394.795990        4579.790039
# 3 2014-09-20               NaN          408.903992                NaN
# 4 2014-09-21               NaN          398.821014                NaN
#
#    tesla_stockprice  sp500_volume  bitcoin_volume  nasdaq_volume  tesla_volume
# 0         17.425333  3.209420e+09        21056800   1.796710e+09    77665500.0
# 1         17.587999  3.235340e+09        34483200   1.774840e+09    55389000.0
# 2         17.288000  4.880220e+09        37919700   3.178490e+09   102163500.0
# 3               NaN           NaN        36863600            NaN           NaN
# 4               NaN           NaN        26580100            NaN           NaN

# %% [markdown]
# ## write

# %%
merged_data.to_csv("financeData_target_variables.csv", index=False)

sp500_data.to_csv("temporary_files/sp500_data.csv", index=False)
tsla_data.to_csv("temporary_files/tsla_data.csv", index=False)
btc_data.to_csv("temporary_files/btc_data.csv", index=False)
nasdaq_data.to_csv("temporary_files/nasdaq_data.csv", index=False)
